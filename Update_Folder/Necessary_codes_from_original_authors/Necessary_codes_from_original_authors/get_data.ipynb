# %%
pip install mega.py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.3 MB 23.0 MB/s
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.1.0
#     Uninstalling tenacity-8.1.0:
#       Successfully uninstalled tenacity-8.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plotly 5.5.0 requires tenacity>=6.2.0, but you have tenacity 5.1.5 which is incompatible.
# ...

# %%
from mega import Mega

mega = Mega()
m = mega.login()

# %%
# Electricity
print('Downloading Electricity dataset...')
m.download_url('https://mega.nz/file/MaUxSTzI#SbVLiltqBzf9wa9C4zoE_goMYZY_rikTXFGodynSTmo')
m.download_url('https://mega.nz/file/lCElEBRA#RonhMz5aO4wDevhXTb6cqg_yjWegs0lRiY6yY2SuAvM')
print('Electricity dataset downloaded')
# Out:
# ...
# Electricity dataset downloaded

# %%
# ETTm1
print('Downloading ETTm1 dataset...')
m.download_url('https://mega.nz/file/8LlFRKKA#1B15mP2Nu8bg2UXBvDvlb2wQtrhgqmr7NBgtgh9GynQ')
m.download_url('https://mega.nz/file/lbVHTKpJ#jIHxfQlx-WWW-tSX7juHsyYYyMrfEiQdGD17jvVINYk')
print('ETTm1 dataset downloaded')

# %%
# Mujoco
print('Downloading Mujoco dataset...')
m.download_url('https://mega.nz/file/YKtwkSjZ#u_yJy3KNZyUfGYCFzwNNU7Nzar232-5r_jrCLSNmq50')
m.download_url('https://mega.nz/file/QXsBgQoS#CjbChp35YZ_sKIjrB0YLyuayfCWHSBuKJR2AZnZJO8k')
print('Mujoco dataset downloading')

# %%
# PTB-XL
print('Downloading PTB-XL dataset 248...')
m.download_url('https://mega.nz/file/wKFmjbQY#9pQCnYAV282xJlkuJ1cAsgklHQj8toYCFylGZl5DC-w')
m.download_url('https://mega.nz/file/UDkByCLY#SwL3NyAhtkJKbvn6PEosnN9mTOZb4yT0PHaW6fMQU3k')
m.download_url('https://mega.nz/file/IOMzTIiI#w3wu0SNnelnDaoyn3cZXyvqTXLlf587SPWsyQOWYESc')

# %%
print('Downloading PTB-XL dataset 1000....')
m.download_url('https://mega.nz/file/ZCtkFbZT#U4lDsYUZx_oiLX8QQVZLg4_bTFEM_xR2Xn3YCoTSPFM')
m.download_url('https://mega.nz/file/IS9Q1ZaT#3syB-EH_s0rI3riTzBnY9CtkGRxiUcBgqwsvig1uEQs')
m.download_url('https://mega.nz/file/oHUlUI4J#T4F3n1UdV0yZwZ1i9NZE_Vz-nHr5uxeYC49oh9jLqo4')

print('PTB-XL datasets downloaded')

# %%
from google.colab import drive
drive.mount('/content/drive')
